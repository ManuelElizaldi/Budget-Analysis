# %%
import requests 
from bs4 import BeautifulSoup

# %%
url = 'https://www.samsclub.com/order/history/inclub'

r = requests.get(url).text

# %%
soup = BeautifulSoup(r, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...
